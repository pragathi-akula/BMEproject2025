# %%
import pandas as pd

# %%
aditirest = pd.read_csv("data.csv")

# %%
aditirest
# Out:
#        Time(s)   EKG(mV)
# 0        0.000  0.243747
# 1        0.005  0.163452
# 2        0.010  0.131165
# 3        0.015  0.065102
# 4        0.020  0.069862
# ...        ...       ...
# 29996  149.980 -0.095393
# 29997  149.985 -0.094143
# 29998  149.990 -0.090441
# 29999  149.995 -0.082748
# 30000  150.000 -0.077771
#
# [30001 rows x 2 columns]

# %%
#| label: resting
aditirest[0:5000].plot.line(x="Time(s)", y="EKG(mV)",figsize=(8,2));

# %%
aditistress = pd.read_csv("data2.csv")

# %%
aditistress
# Out:
#        Time(s)   EKG(mV)
# 0        0.000 -0.069958
# 1        0.005 -0.065318
# 2        0.010 -0.062746
# 3        0.015 -0.050509
# 4        0.020 -0.039306
# ...        ...       ...
# 29996  149.980  0.041831
# 29997  149.985  0.005169
# 29998  149.990 -0.014929
# 29999  149.995 -0.032984
# 30000  150.000 -0.036950
#
# [30001 rows x 2 columns]

# %%
#| label: stress
aditistress[0:5000].plot.line(x="Time(s)", y="EKG(mV)",figsize=(8,2));
